# %% [markdown]
# # STAT 207 Homework 1 [25 points]
#
# ## Understanding Data and Asking Questions

# %% [markdown]
# Due: Thursday, January 29, end of day (11:59 pm CT)*
#
# *Late Submissions: accepted until Tuesday, February 3 at 11:59 pm
# <hr>

# %% [markdown]
# ## Set Up the Data
#
# First, we'll set up the file so that we can complete our data analysis.  We'll import Python packages including pandas, which helps when analyzing a dataset, and visualization packages.  We'll also load in our data and save it as `df` for later analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv('Billionaires.csv')

# %% [markdown]
# We'll work with a data set about all of the world's billionaires from 2024 (https://www.forbes.com/billionaires/).  This data has been scraped from Forbes and prepared for you (https://www.kaggle.com/datasets/vincentcampanaro/forbes-worlds-billionaires-list-2024) and is contained in the "Billionaires.csv" file located in the same folder.
#
# We've read this data in above.
#
# ## Purpose
#
# In this assignment, we will explore and summarize characteristics of the world's billionaires.  You might imagine that you are pursuing one of the following goals:
#
# - working with a client who wants to become a billionaire and therefore are advising them on strategies or characteristics,
# - looking into disparities, advantages, and/or inequalities within the world's billionaires, or
# - exploring the inequitable distribution of wealth among the world's citizens who have amassed the most wealth.
#
# The GitHub portion of this assignment allows you to document and submit your analyses.  The corresponding Gradescope portion of this assignment allows you to summarize and share your results with a stakeholder who may not have the time or expertise to read through your analyses but would like to understand your results.

# %% [markdown]
# ## 1. Understanding the Billionaires Data [1 point]
#
# **a)** Display the first several lines of the data frame.

# %%
df.head(10)
# Out:
#                        Name   Age 2024 Net Worth               Industry  \
# 0  Bernard Arnault & family  75.0          $233B       Fashion & Retail
# 1                 Elon Musk  52.0          $195B             Automotive
# 2                Jeff Bezos  60.0          $194B             Technology
# 3           Mark Zuckerberg  39.0          $177B             Technology
# 4             Larry Ellison  79.0          $141B             Technology
# 5            Warren Buffett  93.0          $133B  Finance & Investments
# 6                Bill Gates  68.0          $128B             Technology
# 7             Steve Ballmer  68.0          $121B             Technology
# 8             Mukesh Ambani  66.0          $116B            Diversified
# 9                Larry Page  51.0          $114B             Technology
#
#      Source of Wealth  Self-Made                Residence    Citizenship  \
# 0                LVMH      False            Paris, France         France
# ...

# %%
#df = df.dropna() #going to forget about this to answer questions in gradescope

# %% [markdown]
# **b)** Extra Gradescope Calculations
#
# I'd suggest turning to Q1 on Gradescope here, using the results of part a above.
#
# I don't anticipate a need to perform any more calculations or analyses for this problem.  This space is available for any optional calculations or analyses that you'd like.

# %%
df.groupby('Industry').size().sort_values(ascending=False).head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Industry'>

# %% [markdown]
# ## 2. Billionaires Data Basics [1 point]
#
# **a)** Use Python to report the dimensions of the data.

# %%
df.shape
# Out:
# (2781, 11)

# %% [markdown]
# **b)** Extra Gradescope Calculations
#
# I'd suggest turning to Q2 on Gradescope here, using the results of Q1 & Q2 above.
#
# I don't anticipate a need to perform any more calculations or analyses for this problem.  This space is available for any optional calculations or analyses that you'd like.

# %% [markdown]
# ## 3. Variable Types [1 point]

# %% [markdown]
# **a)** What is the variable type as recorded in Python for each variable in the Billionaire data?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2781 entries, 0 to 2780
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              2781 non-null   object
#  1   Age               2698 non-null   float64
#  2   2024 Net Worth    2781 non-null   object
#  3   Industry          2781 non-null   object
#  4   Source of Wealth  2781 non-null   object
#  5   Self-Made         2781 non-null   bool
#  6   Residence         2746 non-null   object
#  7   Citizenship       2781 non-null   object
#  8   Gender            2781 non-null   object
#  9   Marital Status    2203 non-null   object
#  10  Children          1705 non-null   float64
# dtypes: bool(1), float64(2), object(8)
# memory usage: 220.1+ KB

# %% [markdown]
# What sticks out is mainly 2024 Net Worth, I would expect it to be saved as an int. Also note age being saved as a float rather than int though it is less concerning.

# %% [markdown]
# **b)** Extra Gradescope Calculations
#
# I'd suggest turning to Q3 on Gradescope here, using the results of part a above.
#
# I don't anticipate a need to perform any more calculations or analyses for this problem.  This space is available for any optional calculations or analyses that you'd like.

# %% [markdown]
# ## 4. Exploring Ages [1 point]
#
# **a)** Explore the ages variable in the dataset using descriptive analytics.  There are multiple ways in which you could do this, including using numerical summaries or graphical visualizations.

# %%
df.groupby('Age').size().sort_values(ascending=False).head(10).plot(kind='box')
# Out:
# <Axes: >

# %%
df['Age'].agg(['min', 'max'])
# Out:
# min     19.0
# max    102.0
# Name: Age, dtype: float64

# %% [markdown]
# **b)** Extra Gradescope Calculations
#
# I'd suggest turning to Q4 on Gradescope here, using the results of part a above.  You'll be asked if there any observations that appear to be unusual for the age variable.
#
# You may optionally further explore the data for Gradescope Q4 in part b.  You can use this section for any additional exploration that you'd like, although there are no points associated with this part.

# %% [markdown]
# ## 5. Asking and Answering Questions [1 point]
#
# **a)** You will pose a question that you can answer using the available data.  Below, use Python to answer your question, using numerical summaries, graphical visualizations, or both.  You will also upload your code and output to Gradescope as either a file upload or pasting your code and output from below.
#
# Be sure that your question requires additional and distinct analysis from what you performed in Question 4.

# %% [markdown]
# Question: Does the industry have any correlation between being selfmade?

# %%
df.groupby("Industry")["Self-Made"].mean().sort_values(ascending=False).plot(kind='bar', figsize=(20,10), fontsize=15)
# Out:
# <Axes: xlabel='Industry'>

# %% [markdown]
# **b)** Extra Gradescope Calculations
#
# I'd suggest turning to Q5 on Gradescope here, using the results of part a above.  I don't anticipate a need to perform any more calculations or analyses for this problem.  This space is available for any optional calculations or analyses that you'd like, although there are no points associated with this part.
#
# You can then complete Q6 on Gradescope, which does not require any analysis.

# %% [markdown]
# ## 6. AI Acknowledgement
#
# Our course policy is that you should write all of your own interpretations and other narrative answers (phrases or sentences) yourself without the assistance of AI.  You may use AI to help guide your code, although you should write all of your own code yourself (not copy-paste from another source) and you should cite your use of AI.  I would encourage you to try to generate any necessary code yourself first using course resources and using AI as a debugging tool if/when you reach an error that you can't figure out or to help you perform any coding tasks that are more advanced than we've demonstrated during class (intended only for projects).
#
# Did you use AI on this assignment?  Did you use other resources outside of our course-provided resources on this assignment?

# %% [markdown]
# I used vscode's ai assistant, I believe it is copilot.

# %% [markdown]
# If you used AI or other resources, answer the following questions to cite your usage.
#
# - Which AI and/or resources did you use?
# - What prompts did you ask it?
# - How did you integrate the responses into your assignment?  Specifically, which questions or parts are associated with this usage?
#
# Note: answering these three questions are enough for our course but may not be enough for a different course or context.

# %% [markdown]
# I used the vscode built in ai. I asked: "how do i call the text size". I used in question 5 as when I enlarged the plot the text remained small and I forgot the correct variable name to modify the default size.

# %% [markdown]
# Remember to keep all your cells and hit the save icon above periodically to checkpoint (save) your results on your local computer. Once you are satisified with your results restart the kernel and run all (Kernel -> Restart & Run All). **Make sure nothing has changed**. Checkpoint and exit (File -> Save and Checkpoint + File -> Close and Halt). Follow the instructions on the Homework 1 Canvas Assignment to submit your notebook to GitHub.  Be sure to also complete the Gradescope component of this assignment.
